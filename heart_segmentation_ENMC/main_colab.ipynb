# %% [markdown]
# A ideia desse código é simplesmente executar o código da Unet para treinamento da Rede, as instruções para uso do código será passada separadamente...
#
# A pasta compartilhada deve ser alocada no gdrive do usuário (O arquivo deve estar no seu Gdrive).
#
# Recomenda-se colocar a pasta no diretório Colab Notebooks/

# %% [markdown]
# O comando para logar no Gdrive é
#
# ```
# from google.colab import drive
# drive.mount('/content/gdrive')
# ```
#
# Não é necessário montar o drive via código se o mesmo for montado via interface...
#
# Para montar a interface é só clicar no ícone de pasta e na opção "Mount Drive"

# %%
#Comando para definir pasta
# %cd drive/My\ Drive/Labic\ Segmentation/heart_segmentation/
# Out:
# /content/drive/My Drive/Labic Segmentation/Heart Segmentation

# %%
pip install tensorflow==1.15

# %%
#Comando para rodar o Python
# !python main.py
# Out:
# Using TensorFlow backend.
# Rodando Pela 1 vez
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...
